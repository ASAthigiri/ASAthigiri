# %%
import tensorflow as tf
vector1 = tf.constant([2.0, 3.0, 4.0])
print(vector1)
# Out:
# tf.Tensor([2. 3. 4.], shape=(3,), dtype=float32)

# %%
vector2 = tf.constant([3.0, 4.0, 5.0])
print(vector2)
# Out:
# tf.Tensor([3. 4. 5.], shape=(3,), dtype=float32)

# %%
print(tf.add(vector1,vector2))
# Out:
# tf.Tensor([5. 7. 9.], shape=(3,), dtype=float32)

# %%
print(vector1*vector2)
# Out:
# tf.Tensor([ 6. 12. 20.], shape=(3,), dtype=float32)

# %%
print(tf.tensordot(vector1,vector2,axes=1))
# Out:
# tf.Tensor(38.0, shape=(), dtype=float32)

# %%
a = tf.constant([[1., 2., 3.], [4., 5., 6.], [7., 8., 9.]])
b = tf.constant([1., 2., 3.])
c = tf.tensordot(a, b, axes=1)
print(c)
# Out:
# tf.Tensor([14. 32. 50.], shape=(3,), dtype=float32)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9bd6f2f0-491e-4302-9fe3-feaa5587de84" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9bd6f2f0-491e-4302-9fe3-feaa5587de84">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('concrete_data_sample.csv')
import pandas as pd
import numpy as np
data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
data.shape
# Out:
# (10, 9)

# %%
data.describe()
# Out:
#            Cement  Blast Furnace Slag  Fly Ash       Water  Superplasticizer  \
# count   10.000000           10.000000     10.0   10.000000         10.000000
# mean   371.060000           83.540000      0.0  205.400000          0.500000
# std    116.826664           59.995318      0.0   30.302915          1.054093
# min    198.600000            0.000000      0.0  162.000000          0.000000
# 25%    282.625000           23.750000      0.0  175.500000          0.000000
# 50%    356.250000          104.500000      0.0  228.000000          0.000000
# 75%    451.250000          127.800000      0.0  228.000000          0.000000
# max    540.000000          142.500000      0.0  228.000000          2.500000
#
#        Coarse Aggregate  Fine Aggregate         Age   Strength
# count         10.000000       10.000000   10.000000  10.000000
# mean         972.040000      649.050000  159.000000  47.982000
# std           55.820092       73.254674  159.220323  13.213437
# ...

# %%
data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
data_columns = data.columns
predictors = data[data_columns[data_columns != 'Strength']]
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target = data['Strength']
pre_norms = (predictors - predictors.mean() / predictors.std())
pre_norms.head()
# Out:
#        Cement  Blast Furnace Slag  Fly Ash       Water  Superplasticizer  \
# 0  536.823842           -1.392442      NaN  155.221774          2.025658
# 1  536.823842           -1.392442      NaN  155.221774          2.025658
# 2  329.323842          141.107558      NaN  221.221774         -0.474342
# 3  329.323842          141.107558      NaN  221.221774         -0.474342
# 4  195.423842          131.007558      NaN  185.221774         -0.474342
#
#    Coarse Aggregate  Fine Aggregate         Age
# 0       1022.586199      667.139814   27.001384
# 1       1037.586199      667.139814   27.001384
# 2        914.586199      585.139814  269.001384
# 3        914.586199      585.139814  364.001384
# 4        960.986199      816.639814  359.001384

# %%
n_cols = pre_norms.shape[1]
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
def regression():
    model = Sequential()
    model.add(Dense(50, activation='relu', input_shape = (n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    model.compile(optimizer ='adam', loss='mean_squared_error')
    return model
model = regression()
model.fit(pre_norms, target, validation_split=.3, epochs=25, verbose=2)
# Out:
# Epoch 1/25
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 - 2s - 2s/step - loss: nan - val_loss: nan
# Epoch 2/25
# 1/1 - 0s - 372ms/step - loss: nan - val_loss: nan
# Epoch 3/25
# 1/1 - 0s - 90ms/step - loss: nan - val_loss: nan
# Epoch 4/25
# 1/1 - 0s - 94ms/step - loss: nan - val_loss: nan
# Epoch 5/25
# 1/1 - 0s - 176ms/step - loss: nan - val_loss: nan
# Epoch 6/25
# 1/1 - 0s - 99ms/step - loss: nan - val_loss: nan
# Epoch 7/25
# 1/1 - 0s - 87ms/step - loss: nan - val_loss: nan
# Epoch 8/25
# 1/1 - 0s - 214ms/step - loss: nan - val_loss: nan
# Epoch 9/25
# 1/1 - 0s - 140ms/step - loss: nan - val_loss: nan
# Epoch 10/25
# 1/1 - 0s - 132ms/step - loss: nan - val_loss: nan
# Epoch 11/25
# ...
